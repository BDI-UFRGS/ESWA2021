# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame([['FT1','B1',0.524],['FT1','B2',0.480],['FT1','B3',0.437],['FT1','P1',0.522],['FT1','P2',0.615],
                    ['FT2','B1',0.511],['FT2','B2',0.463],['FT2','B3',0.434],['FT2','P1',0.490],['FT2','P2',0.605],
                    ['FT3','B1',0.513],['FT3','B2',0.473],['FT3','B3',0.423],['FT3','P1',0.502],['FT3','P2',0.611],
                    ['FT4','B1',0.496],['FT4','B2',0.434],['FT4','B3',0.418],['FT4','P1',0.462],['FT4','P2',0.579],
                    ['GV1','B1',0.500],['GV1','B2',0.438],['GV1','B3',0.428],['GV1','P1',0.511],['GV1','P2',0.622],
                    ['GV2','B1',0.523],['GV2','B2',0.471],['GV2','B3',0.454],['GV2','P1',0.538],['GV2','P2',0.635],
                    ['GV3','B1',0.515],['GV3','B2',0.465],['GV3','B3',0.433],['GV3','P1',0.526],['GV3','P2',0.619],
                    ['W2V','B1',0.467],['W2V','B2',0.436],['W2V','B3',0.392],['W2V','P1',0.476],['W2V','P2',0.584],],columns=['Dataset','Approach','val'])



ax = df.pivot(index="Approach", columns="Dataset", values="val").plot(kind='bar',width=0.8)
plt.axhline(0.635, color='blue', linestyle='dashed', linewidth=1, label = "Best overall")
plt.axhline(0.524, color='red', linestyle='dashed', linewidth=1, label = 'Best baseline')
plt.ylabel("Micro-F1 Score")

plt.ylim((0,1))

labels = ["FT1", "FT2", "FT3", "FT4", "GV1", "GV2", "GV3", "W2V", "Best baseline", "Best Overall"]

handles, _ = ax.get_legend_handles_labels()
plt.legend(handles= handles[2:] + handles[0:2], loc="lower center", ncol=4, bbox_to_anchor=(0.5,-0.42), frameon=False)

plt.show()

# %%
df = pd.DataFrame([['FT1','B1',0.719],['FT1','B2',0.690],['FT1','B3',0.726],['FT1','P1',0.762],['FT1','P2',0.825],
                    ['FT2','B1',0.703],['FT2','B2',0.665],['FT2','B3',0.711],['FT2','P1',0.744],['FT2','P2',0.806],
                    ['FT3','B1',0.705],['FT3','B2',0.673],['FT3','B3',0.701],['FT3','P1',0.735],['FT3','P2',0.830],
                    ['FT4','B1',0.690],['FT4','B2',0.662],['FT4','B3',0.704],['FT4','P1',0.720],['FT4','P2',0.792],
                    ['GV1','B1',0.685],['GV1','B2',0.620],['GV1','B3',0.665],['GV1','P1',0.730],['GV1','P2',0.814],
                    ['GV2','B1',0.714],['GV2','B2',0.658],['GV2','B3',0.699],['GV2','P1',0.756],['GV2','P2',0.814],
                    ['GV3','B1',0.715],['GV3','B2',0.673],['GV3','B3',0.698],['GV3','P1',0.747],['GV3','P2',0.817],
                    ['W2V','B1',0.673],['W2V','B2',0.630],['W2V','B3',0.689],['W2V','P1',0.719],['W2V','P2',0.797],],columns=['Dataset','Approach','val'])



ax = df.pivot(index="Approach", columns="Dataset", values="val").plot(kind='bar',width=0.8)
plt.axhline(0.830, color='blue', linestyle='dashed', linewidth=1, label = "Best overall")
plt.axhline(0.726, color='red', linestyle='dashed', linewidth=1, label = 'Best baseline')
plt.ylabel("Micro-F1 Score")

plt.ylim((0,1))

labels = ["FT1", "FT2", "FT3", "FT4", "GV1", "GV2", "GV3", "W2V", "Best baseline", "Best Overall"]

handles, _ = ax.get_legend_handles_labels()
plt.legend(handles= handles[2:] + handles[0:2], loc="lower center", ncol=4, bbox_to_anchor=(0.5,-0.42), frameon=False)

plt.show()

# %%
df = pd.DataFrame([['FT1','B1',0.866],['FT1','B2',0.864],['FT1','B3',0.892],['FT1','P1',0.911],['FT1','P2',0.934],
                    ['FT2','B1',0.867],['FT2','B2',0.845],['FT2','B3',0.902],['FT2','P1',0.913],['FT2','P2',0.933],
                    ['FT3','B1',0.858],['FT3','B2',0.846],['FT3','B3',0.886],['FT3','P1',0.912],['FT3','P2',0.929],
                    ['FT4','B1',0.859],['FT4','B2',0.835],['FT4','B3',0.893],['FT4','P1',0.909],['FT4','P2',0.923],
                    ['GV1','B1',0.848],['GV1','B2',.834],['GV1','B3',0.888],['GV1','P1',0.909],['GV1','P2',0.921],
                    ['GV2','B1',0.859],['GV2','B2',0.852],['GV2','B3',0.903],['GV2','P1',0.911],['GV2','P2',0.925],
                    ['GV3','B1',0.863],['GV3','B2',0.857],['GV3','B3',0.898],['GV3','P1',0.909],['GV3','P2',0.934],
                    ['W2V','B1',0.846],['W2V','B2',0.846],['W2V','B3',0.887],['W2V','P1',0.907],['W2V','P2',0.915],],columns=['Dataset','Approach','val'])



ax = df.pivot(index="Approach", columns="Dataset", values="val").plot(kind='bar',width=0.8)
plt.axhline(0.934, color='blue', linestyle='dashed', linewidth=1, label = "Best overall")
plt.axhline(0.903, color='red', linestyle='dashed', linewidth=1, label = 'Best baseline')
plt.ylabel("Micro-F1 Score")

plt.ylim((0,1))

labels = ["FT1", "FT2", "FT3", "FT4", "GV1", "GV2", "GV3", "W2V", "Best baseline", "Best Overall"]

handles, _ = ax.get_legend_handles_labels()
plt.legend(handles= handles[2:] + handles[0:2], loc="lower center", ncol=4, bbox_to_anchor=(0.5,-0.42), frameon=False)

plt.show()
